# %%
from wave_client import WaveClient
import pandas as pd
from utils import (
    load_environment_variables,
)

# %%
# Load environment variables and connect to WAVE backend
RESEARCHER_API_KEY, EXPERIMENTEE_API_KEY, WAVE_BACKEND_URL = load_environment_variables()

print(f"🔍 Connecting to WAVE backend...")
print(f"📡 Backend URL: {WAVE_BACKEND_URL}")
print(f"🔑 Using Researcher API key ending in: ...{RESEARCHER_API_KEY[-4:]}")

client = WaveClient(api_key=RESEARCHER_API_KEY, base_url=WAVE_BACKEND_URL)
# Out:
# Present working directory: c:\Users\mcpro\OneDrive\Documents\WAVE LAB\Code\socialNavigationTR\tools
# Loading environment variables from c:\Users\mcpro\OneDrive\Documents\WAVE LAB\Code\socialNavigationTR\tools/.env
# 🔍 Connecting to WAVE backend...
# 📡 Backend URL: https://wave-backend-production-8781.up.railway.app
# 🔑 Using Researcher API key ending in: ...bsik

# %%
## use this (uncomment it) to see what commands exist 
## (allow the scrollable option at the bottom to see all commands)

# help(client.experiments)
# help(client.experiment_data)

# %%
# Get all experiments to see which one to analyze
experiments = await client.experiments.list(skip=0, limit=200)
print(f"Found {len(experiments)} experiments\n")

# Sort by creation date (most recent first) and show up to 5
sorted_experiments = sorted(experiments, key=lambda x: x.get('created_at', ''), reverse=True)[:10]
print(f"Showing {len(sorted_experiments)} most recent experiments (of {len(experiments)} total)\n")

# Display experiment info
for i, exp in enumerate(experiments, 1):
    print(f"{i}. Experiment UUID: {exp['uuid']}")
    print(f"   Description: {exp.get('description', 'N/A')}")
    print(f"   Type ID: {exp.get('experiment_type_id', 'N/A')}")
    print(f"   Created: {exp.get('created_at', 'N/A')[:10]}")
    print(f"   Tags: {', '.join(exp.get('tags', []))}")
    print("-" * 70)
# Out:
# Found 49 experiments
#
# Showing 10 most recent experiments (of 49 total)
#
# 1. Experiment UUID: 44559e7e-fde7-4d9b-895a-39ca29287804
#    Description: surprisedelab_rectangle_prod
#    Type ID: 23
#    Created: 2026-03-19
#    Tags:
# ----------------------------------------------------------------------
# 2. Experiment UUID: 7adbc62f-1786-434d-86ba-759de4347764
#    Description: suprisedelabtime_reprodur_prod
#    Type ID: 25
#    Created: 2026-03-22
#    Tags:
# ----------------------------------------------------------------------
# 3. Experiment UUID: ef359255-c25d-4f04-aa98-727632abafff
#    Description: suprisedelabtime_genderJudge_prod
#    Type ID: 26
#    Created: 2026-03-23
#    Tags:
# ----------------------------------------------------------------------
# 4. Experiment UUID: 0effc73a-0d82-49a7-af3c-73369939a469
#    Description: surprisedelab_rectangle_genderJudgetext_prod
#    Type ID: 28
#    Created: 2026-03-23
#    Tags:
# ----------------------------------------------------------------------
# 5. Experiment UUID: cd5cba04-c3f4-49c7-a7e2-41ad885e9fce
#    Description: surprisedelab_rectangle500_genderJudgetext_prod
#    Type ID: 29
#    Created: 2026-03-25
#    Tags:
# ----------------------------------------------------------------------
# 6. Experiment UUID: f31e1f30-b826-4286-89dc-6f221fcd69f2
#    Description: suprisedelabtime_multitrial_prod
#    Type ID: 30
#    Created: 2026-03-27
#    Tags:
# ----------------------------------------------------------------------
# 7. Experiment UUID: 0d0a4584-d802-4032-adff-7d47b430685f
#    Description: surprisedelab_multitrial_prod
#    Type ID: 31
#    Created: 2026-03-29
#    Tags:
# ----------------------------------------------------------------------
# 8. Experiment UUID: e0b98e54-6533-45d7-9ee0-66708725164a
#    Description: suprisedelabtime_ovalface_prod
#    Type ID: 32
#    Created: 2026-04-20
#    Tags:
# ----------------------------------------------------------------------
# 9. Experiment UUID: 95e55583-a1db-451f-86fe-49e7a79e8ab7
#    Description: surprisedelab_distancerepro_prod
#    Type ID: 33
#    Created: 2026-04-20
#    Tags:
# ----------------------------------------------------------------------
# 10. Experiment UUID: 30267460-6eac-4b90-9bbb-4b116e0d9134
#    Description: epcd_33cabinet_prod
#    Type ID: 34
#    Created: 2026-04-21
#    Tags:
# ----------------------------------------------------------------------
# 11. Experiment UUID: 3b88d503-b421-4734-94b0-3cab8bcc4ffe
#    Description: surprisedelab_distancerepro_calcfix_prod
#    Type ID: 35
#    Created: 2026-04-27
#    Tags:
# ----------------------------------------------------------------------
# 12. Experiment UUID: 1f4f1417-9b60-41e0-949e-3b6e8c911b3d
#    Description: epcd_33cabinet_grayscale_prod
#    Type ID: 36
#    Created: 2026-05-01
#    Tags:
# ----------------------------------------------------------------------
# 13. Experiment UUID: 0ef3dc5a-b6d2-4c17-90ee-e83880a15c5f
#    Description: shadow_afc_prod
#    Type ID: 6
#    Created: 2026-01-08
#    Tags:
# ----------------------------------------------------------------------
# 14. Experiment UUID: ef73f4c5-f996-4ba4-831e-66c6a8429570
#    Description: suprisedelabtime_monitorface_prod
#    Type ID: 37
#    Created: 2026-05-02
#    Tags:
# ----------------------------------------------------------------------
# 15. Experiment UUID: 56332cb3-b54a-4828-be3e-bbc786118885
#    Description: jspsych_circles_prod
#    Type ID: 7
#    Created: 2026-01-09
#    Tags:
# ----------------------------------------------------------------------
# 16. Experiment UUID: 89a1bb5b-b06b-4672-9de5-68bebd96192e
#    Description: socialNavigation_base_prod
#    Type ID: 38
#    Created: 2026-05-04
#    Tags:
# ----------------------------------------------------------------------
# 17. Experiment UUID: 1b0e41ac-da96-4fe1-b012-d10c2618720d
#    Description: suprisedelabtime_window_prod
#    Type ID: 39
#    Created: 2026-05-06
#    Tags:
# ----------------------------------------------------------------------
# 18. Experiment UUID: 530a5fd4-2485-4d88-9c83-5acead500b94
#    Description: surprisedelab_pos
#    Type ID: 11
#    Created: 2026-02-02
#    Tags:
# ----------------------------------------------------------------------
# 19. Experiment UUID: dbaf1cae-c960-41f7-8dba-1e445f2e0b30
#    Description: surprisedelab_distancerepro_silhouetteresp_prod
#    Type ID: 40
#    Created: 2026-05-10
#    Tags:
# ----------------------------------------------------------------------
# 20. Experiment UUID: aeb293f8-2206-46a9-9d46-b21092526504
#    Description: shadows_afc_numtask_prod
#    Type ID: 12
#    Created: 2026-02-05
#    Tags:
# ----------------------------------------------------------------------
# 21. Experiment UUID: 4a1d1324-64ab-464f-9787-b19058002f11
#    Description: shadows_afc_shortnum_prod
#    Type ID: 13
#    Created: 2026-02-05
#    Tags:
# ----------------------------------------------------------------------
# 22. Experiment UUID: 6023b648-b34a-4a61-89e8-2589fb1b6e39
#    Description: epcd_cup_prod
#    Type ID: 15
#    Created: 2026-02-12
#    Tags:
# ----------------------------------------------------------------------
# 23. Experiment UUID: 3d22a808-1884-49b5-9b6d-74dbc4507e27
#    Description: shadows_afc_bevel_prod
#    Type ID: 16
#    Created: 2026-02-20
#    Tags:
# ----------------------------------------------------------------------
# 24. Experiment UUID: 1369e51f-5a38-4b2b-afcc-3663b08a75b3
#    Description: epcd_cup_moreitems_prod
#    Type ID: 17
#    Created: 2026-02-27
#    Tags:
# ----------------------------------------------------------------------
# 25. Experiment UUID: 4a7ac609-d758-441f-aa84-b82af9f4eb5f
#    Description: shadows_afc_consistentposition_prod
#    Type ID: 18
#    Created: 2026-03-02
#    Tags:
# ----------------------------------------------------------------------
# 26. Experiment UUID: 8e152171-c0c8-402f-b5f8-80ec4451f3f2
#    Description: epcd_big_prod
#    Type ID: 19
#    Created: 2026-03-07
#    Tags:
# ----------------------------------------------------------------------
# 27. Experiment UUID: b3a20dff-2591-4338-ae7e-8a66b9f33edf
#    Description: surprisedelab_samebody_prod
#    Type ID: 20
#    Created: 2026-03-13
#    Tags:
# ----------------------------------------------------------------------
# 28. Experiment UUID: ef776417-3de0-419d-bfd6-b0add1277ae1
#    Description: epcd_expand_prod
#    Type ID: 21
#    Created: 2026-03-13
#    Tags:
# ----------------------------------------------------------------------
# 29. Experiment UUID: 75f78b97-4aba-4141-a848-056161413362
#    Description: surprisedelab_samebody_dispdur_prod
#    Type ID: 22
#    Created: 2026-03-17
#    Tags:
# ----------------------------------------------------------------------
# 30. Experiment UUID: b8976572-411d-43c9-9733-7a58c71328d3
#    Description: suprisedelabtime_multitrialcontinued_screenside_prod
#    Type ID: 41
#    Created: 2026-05-11
#    Tags:
# ----------------------------------------------------------------------
# 31. Experiment UUID: 869ea930-ad91-445f-b50a-927ae8a9ad1b
#    Description: epcd_pp_handtype_prod
#    Type ID: 42
#    Created: 2026-06-25
#    Tags:
# ----------------------------------------------------------------------
# 32. Experiment UUID: 0660e445-52e1-4401-9f91-61ff9937f706
#    Description: epcd_pp_handtypefix_prod
#    Type ID: 43
#    Created: 2026-06-27
#    Tags:
# ----------------------------------------------------------------------
# 33. Experiment UUID: bb4d13ff-59a7-4804-8bb1-a2d6f26b5e36
#    Description: epcd_singleblock_prod
#    Type ID: 44
#    Created: 2026-07-01
#    Tags:
# ----------------------------------------------------------------------
# 34. Experiment UUID: 3af0997c-18ab-45db-bbca-79d914b16104
#    Description: socialNavigation_contrast_prod
#    Type ID: 45
#    Created: 2026-07-02
#    Tags:
# ----------------------------------------------------------------------
# 35. Experiment UUID: f429667e-21d1-4a16-b4e1-fb9e80588d12
#    Description: Test experiment for socialNavigation_TR - TEST_socialNavigation_TR_20260727_155933
#    Type ID: 54
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 36. Experiment UUID: a205068b-22b5-424a-a055-8143a10b71f8
#    Description: suprisedelabtime_femalebody_prod
#    Type ID: 48
#    Created: 2026-07-12
#    Tags:
# ----------------------------------------------------------------------
# 37. Experiment UUID: 82212fa3-ef7d-47ad-bc58-f0858b1b5467
#    Description: epcd_singleblock_flexconfigs_prod
#    Type ID: 49
#    Created: 2026-07-13
#    Tags:
# ----------------------------------------------------------------------
# 38. Experiment UUID: eedf6776-d27b-4d1c-a4f4-ad76263dc052
#    Description: Test experiment for socialNavigation_mobility - TEST_socialNavigation_mobility_20260714_124133
#    Type ID: 50
#    Created: 2026-07-14
#    Tags: test
# ----------------------------------------------------------------------
# 39. Experiment UUID: 0ad21f38-874d-4a84-8572-6c4b994ffedf
#    Description: socialNavigation_mobility_prod
#    Type ID: 50
#    Created: 2026-07-14
#    Tags:
# ----------------------------------------------------------------------
# 40. Experiment UUID: 15fc9802-8d7d-4732-8cb6-243c639a4166
#    Description: Test experiment for suprisedelabtime_rotation - TEST_suprisedelabtime_rotation_20260720_135849
#    Type ID: 51
#    Created: 2026-07-20
#    Tags: test
# ----------------------------------------------------------------------
# 41. Experiment UUID: f0396d41-b04d-450a-a40b-5fa06744c19d
#    Description: suprisedelabtime_rotation_prod
#    Type ID: 51
#    Created: 2026-07-20
#    Tags:
# ----------------------------------------------------------------------
# 42. Experiment UUID: 55e41ba3-509e-4bc7-ba06-12c2a3383438
#    Description: suprisedelabtime_headsonly_prod
#    Type ID: 47
#    Created: 2026-07-08
#    Tags:
# ----------------------------------------------------------------------
# 43. Experiment UUID: d93b6e50-82b2-4a3d-9633-94cc1732ae53
#    Description: Test experiment for suprisedelabtime_staticbigwindow - TEST_suprisedelabtime_staticbigwindow_20260727_020616
#    Type ID: 52
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 44. Experiment UUID: 486d4c4d-2005-49f3-9dfe-c0c35761b6b2
#    Description: Test experiment for suprisedelabtime_staticbigwindow - TEST_suprisedelabtime_staticbigwindow_20260727_022119
#    Type ID: 52
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 45. Experiment UUID: 9a41d388-f40a-4c5a-8200-27ad7d948bab
#    Description: suprisedelabtime_staticbigwindow_prod
#    Type ID: 52
#    Created: 2026-07-27
#    Tags:
# ----------------------------------------------------------------------
# 46. Experiment UUID: a299301a-685a-4cb8-82ee-e33b1b52652a
#    Description: Test experiment for socialNavigationTR - TEST_socialNavigationTR_20260727_152114
#    Type ID: 53
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 47. Experiment UUID: ba65c4a3-9af2-4a51-86df-ba4e1d0a6171
#    Description: Test experiment for socialNavigation_TR - TEST_socialNavigation_TR_20260727_154658
#    Type ID: 54
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 48. Experiment UUID: 8bf5f25d-b78f-4fee-80b2-2f8556be5a75
#    Description: Test experiment for socialNavigation_TR - TEST_socialNavigation_TR_20260727_155814
#    Type ID: 54
#    Created: 2026-07-27
#    Tags: test
# ----------------------------------------------------------------------
# 49. Experiment UUID: 28f9e2ee-a7db-4bc4-8a3a-ffc9c821cb23
#    Description: socialNavigation_TR_prod
#    Type ID: 54
#    Created: 2026-07-27
#    Tags:
# ----------------------------------------------------------------------

# %%
# Put the necessary info into the variables below 
selected_experiment_uuid = "28f9e2ee-a7db-4bc4-8a3a-ffc9c821cb23" 

# Get all data from that experiment
print(f"\n📊 Fetching data for experiment {selected_experiment_uuid}...")
experiment_data_df = await client.experiment_data.get_all_data(
    experiment_id=selected_experiment_uuid
)

print(f"Total records: {len(experiment_data_df)}")
# print(experiment_data_df)
# Out:
# 📊 Fetching data for experiment 28f9e2ee-a7db-4bc4-8a3a-ffc9c821cb23...
# Total records: 12086

# %%
# Filter and save into .csv file
full_df = (experiment_data_df.query("(participant_id != '12345678') and (participant_id != '5f031154d2fab64a687af6db') and (participant_id != '69a335cdd0de6030573dbd20')")
           .sort_values(by="timestamp",ascending=True))
full_df.to_csv("data/dataframe_full.csv", index = False)

answer_df = full_df.query("trial_category == 'answerexpt'")
answer_df.to_csv("data/dataframe_answer.csv", index = False)

attention_df = full_df.query("trial_category == 'afcexpt'")
attention_df.to_csv("data/dataframe_attention.csv", index = False)

debrief_df = full_df.query("trial_category == 'debriefexpt'")
debrief_df.to_csv("data/dataframe_debrief.csv", index = False)

# %%
# Example of how to pull out only a few specific columns 

selected_columns = answer_df[["response","response_time"]]
print(selected_columns)
# Out:
#       response  response_time
# 11585        0         2380.0
# 11580        0         1013.0
# 11575        0         1300.0
# 11570        0         1045.0
# 11565        0          860.0
# ...        ...            ...
# 21           0          684.0
# 16           0          799.0
# 11           0          666.0
# 6            0          682.0
# 1            0          544.0
#
# [2241 rows x 2 columns]
